# %%
# !pip iinstallnstall -U ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 48.6 MB/s eta 0:00:00
# ...

# %%
# Step 1: Download the dataset and save as roboflow.zip
# !curl -L "https://app.roboflow.com/ds/UUuHAJiSpr?key=gk33EUBOPq" -o roboflow.zip

# Step 2: Unzip into /content/dataset
# !unzip -o roboflow.zip -d /content/dataset

# Step 3: Remove the zip file to save space
# !rm roboflow.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#  extracting: /content/dataset/train/images/Twalv0995_jpg.rf.973b56bf7ed6d10796fbf804a2ad7ac2.jpg
#  extracting: /content/dataset/train/images/Twalv1015_jpg.rf.1c2a88bd87af0a2e8802286cf800739f.jpg
#  extracting: /content/dataset/train/images/Twalv1015_jpg.rf.82c23fb4ebe6e195cbf5ddc0b8e51834.jpg
#  extracting: /content/dataset/train/images/Twalv1015_jpg.rf.93ac7388c38bf6c9899c59ae12315e6e.jpg
#  extracting: /content/dataset/train/images/Twalv1015_jpg.rf.d0decfa7bd4cb437bc6c681fc18e2b44.jpg
#  extracting: /content/dataset/train/images/Twalv1052_jpg.rf.2c191218097e3d35fb201cc73de481e4.jpg
#  extracting: /content/dataset/train/images/Twalv1052_jpg.rf.7a04ef1b034161d7f1f4c321e086a2c4.jpg
#  extracting: /content/dataset/train/images/Twalv1069_jpg.rf.2bd9c01f2bebf5a330f34872ceb85f3d.jpg
#  extracting: /content/dataset/train/images/Twalv1069_jpg.rf.4f71cfbc0fbd7a762db4971647d61a95.jpg
# ...

# %%
import os

# List files in the current directory
os.listdir('/content')
# Out:
# ['.config', 'dataset', 'best.pt', 'last.pt', 'sample_data']

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from ultralytics import YOLO
model = YOLO('/content/drive/MyDrive/best.pt')

# 5️⃣ Fine-tune on your dataset
model.train(
    data='/content/dataset/data.yaml',  # path to your Roboflow dataset
    epochs=80,                           # fine-tuning epochs
    imgsz=640,                           # image size
    batch=16,                            # adjust based on GPU memory
    lr0=1e-4,                            # lower learning rate for fine-tuning
    freeze=10                             # optional: freeze backbone initially
)
# Out:
# Ultralytics 8.3.204 🚀 Python-3.12.11 torch-2.8.0+cu126 CUDA:0 (Tesla T4, 15095MiB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# !pip install -U ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 34.3 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/Colab_Backup/best90.pt")

# export ONNX FP16
model.export(format="onnx", half=True)

# export TFLite FP16
model.export(format="tflite", half=True)
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# Ultralytics 8.3.214 🚀 Python-3.12.12 torch-2.8.0+cu126 CPU (Intel Xeon CPU @ 2.00GHz)
# WARNING ⚠️ half=True only compatible with GPU export, i.e. use device=0, setting half=False.
# 💡 ProTip: Export to OpenVINO format for best performance on Intel hardware. Learn more at https://docs.ultralytics.com/integrations/openvino/
# Model summary (fused): 92 layers, 25,842,655 parameters, 0 gradients, 78.7 GFLOPs
#
# PyTorch: starting from '/content/drive/MyDrive/Colab_Backup/best90.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 9, 8400) (49.6 MB)
# ...

# %%
# !mkdir -p /content/drive/MyDrive/Colab_Backup/APPY
# !cp -r /content/drive/MyDrive/Colab_Backup/best90_saved_model/* /content/drive/MyDrive/Colab_Backup/APPY/

# %%
from ultralytics import YOLO

# Load your trained model
model = YOLO("/content/drive/MyDrive/Colab_Backup/best90.pt")

# Print class names
print("Model Classes:", model.names)
# Out:
# Model Classes: {0: 'boots', 1: 'gloves', 2: 'helmet', 3: 'human', 4: 'vest'}
